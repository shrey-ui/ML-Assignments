# %% [markdown]
# # Shreyans Murkute (E20CSE415)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import pyplot

# %% [markdown]
# ## Part A

# %% [markdown]
# ### 1

# %%
df = pd.read_csv("Iris.csv")

# %% [markdown]
# ### 2

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# ### 3

# %%
df['Species'].value_counts()
# Out:
# Iris-versicolor    50
# Iris-setosa        50
# Iris-virginica     50
# Name: Species, dtype: int64

# %% [markdown]
# ## Part B

# %% [markdown]
# ### a

# %%
species = df['Species'].value_counts()
plt.bar(x = species.index, height=species.values, color=['red', 'green', 'blue'])
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# ### b

# %%
plt.plot(df.Id, df['SepalLengthCm'], linestyle= 'dotted')

# %% [markdown]
# ### c

# %%
x = df['SepalLengthCm']
y = np.sin(x)
z = np.cos(x)
plt.plot(x,y)
plt.plot(x,z)

# %% [markdown]
# ### d

# %%
x = df["SepalLengthCm"]
plt.hist(x, bins = 20, color = "green")
plt.title("Sepal Length in cm")
plt.xlabel("Sepal_Length_cm")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# ### e

# %%
a = df['Species'].value_counts()
species = a.index
count = a.values
colors= ['lightblue','lightgreen','gold']
plt.pie(count, labels = species, colors=colors)
plt.show()

# %% [markdown]
# ## Part C

# %% [markdown]
# ### f

# %%
sns.FacetGrid(df, height = 6).map(plt.scatter, 'Id','PetalLengthCm').add_legend()

# %% [markdown]
# ### g

# %%
sns.FacetGrid(df, hue ="Species", height = 6).map(plt.scatter, 'Id','PetalLengthCm').add_legend()

# %% [markdown]
# ### h

# %%
fig, ax = pyplot.subplots(figsize =(9, 7))
sns.violinplot(ax = ax, 
               x = df["Species"], 
               y = df["SepalLengthCm"] )
# Out:
# <AxesSubplot:xlabel='Species', ylabel='SepalLengthCm'>

# %% [markdown]
# ### i

# %%
sns.pairplot(df, hue = 'Species',height =4)
plt.show()

# %% [markdown]
# ### j

# %%
df.corr()
# Out:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.716676     -0.397729       0.882747
# SepalLengthCm  0.716676       1.000000     -0.109369       0.871754
# SepalWidthCm  -0.397729      -0.109369      1.000000      -0.420516
# PetalLengthCm  0.882747       0.871754     -0.420516       1.000000
# PetalWidthCm   0.899759       0.817954     -0.356544       0.962757
#
#                PetalWidthCm
# Id                 0.899759
# SepalLengthCm      0.817954
# SepalWidthCm      -0.356544
# PetalLengthCm      0.962757
# PetalWidthCm       1.000000

# %% [markdown]
# ### k

# %%
sns.heatmap(corr)
# Out:
# <AxesSubplot:>
